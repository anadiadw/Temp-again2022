# %%
from random import *

length = 4
cont = ["S", "T"]

print("\nBismillah!")
s = choice(cont)
s2 = []
while True:
    x = choice(cont)
    if not s2 or s2.count(s[-1] + x) < length:
        print("adding")
        s2.append(s[-1] + x)
        print(s[-1] + x)
        s += x        
        print(s2.count(s[-1] + x))
        print(s)
    if len(s2) == length*4: break

print("\n\n")
print(s)
print(s2)
print(s2.count("SS"),
      s2.count("ST"),
      s2.count("TS"),
      s2.count("TT"),
      len(s),
      len(s2))

print("\n\nAlhumdulilaah!")
print("\nOmar solved it! may Allah ease his troubles ameen!")
# Out:
# Bismillah!
# adding
# TS
# 0
# TS
# adding
# ST
# 0
# TST
# adding
# TS
# 0
# TSTS
# adding
# SS
# 1
# TSTSS
# adding
# SS
# 2
# TSTSSS
# adding
# SS
# 3
# TSTSSSS
# adding
# ST
# 0
# TSTSSSST
# adding
# TT
# 1
# TSTSSSSTT
# adding
# TT
# 2
# TSTSSSSTTT
# adding
# TS
# 3
# TSTSSSSTTTS
# adding
# SS
# 4
# TSTSSSSTTTSS
# adding
# ST
# 2
# TSTSSSSTTTSST
# adding
# TS
# 4
# TSTSSSSTTTSSTS
# adding
# ST
# 2
# TSTSSSSTTTSSTST
# adding
# TT
# 3
# TSTSSSSTTTSSTSTT
# adding
# TT
# 4
# TSTSSSSTTTSSTSTTT
#
#
#
# TSTSSSSTTTSSTSTTT
# ['TS', 'ST', 'TS', 'SS', 'SS', 'SS', 'ST', 'TT', 'TT', 'TS', 'SS', 'ST', 'TS', 'ST', 'TT', 'TT']
# 4 4 4 4 17 16
#
#
# Alhumdulilaah!
#
# Omar solved it! may Allah ease his troubles ameen!
