# %% [markdown]
# ## Only to run once during one session

# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
import math
from heapq import merge
from random import *
import scipy as sp
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt

# %%
pt_SM = []
ls_runSM = []

# %%
data_dir = '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/SONA_data-selected/SONA_data/'
dir_ext = [f for f in listdir(data_dir)]
pt_dir_lst = []
for i in dir_ext:
    pt_dir = data_dir + i
    pt_dir_lst.append(pt_dir)

# %% [markdown]
# ## For each participant

# %%
pt_dir = pt_dir_lst[1]
pt_dir
# Out:
# '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/SONA_data-selected/SONA_data/emt_33'

# %%
encoding_files = []
tempdist_files = []
srcmem_files = []
for pt in pt_dir:
    pt_files = [f for f in listdir(pt_dir) if isfile(join(pt_dir, f))]

for a in pt_files:
    if a[-4:] == '.csv' and 'encoding' in a:
        encoding_files.append(pt_dir + '/' + a)
    if a[-4:] == '.csv' and 'temp_dist' in a:
        tempdist_files.append(pt_dir + '/' + a)
    if a[-4:] == '.csv' and 'src_mem' in a:
        srcmem_files.append(pt_dir + '/' + a)

# %%
#1 add in column for pt number and run number
#2 concat all the run csvs for each test
#3 drop NAs
len(pt_files)
# Out:
# 48

# %%
srcmemdf = []
rn1 = srcmem_files[0]
dt1 = pd.DataFrame(pd.read_csv(rn1, header = 0))
dt1.columns = dt1.columns.str.replace(".", "_")
dt1['run_num'] = '1'
pt_num = dt1.participant[2]
type(dt1)
srcmemdf.append(dt1)
for b in srcmem_files[1:]:
    dt = pd.DataFrame(pd.read_csv(b, header = 0))
    dt.columns = dt.columns.str.replace(".", "_")
    dt['run_num'] = b[-32]
    srcmemdf.append(dt)
allSM_df = pd.concat(srcmemdf)
allSM_df = allSM_df.dropna(subset=['test_object', 'correct_context', 'tested_valence'])

# %%
r1= allSM_df.loc[allSM_df['run_num'] == '1']
r2= allSM_df.loc[allSM_df['run_num'] == '2']
r3= allSM_df.loc[allSM_df['run_num'] == '3']
r4= allSM_df.loc[allSM_df['run_num'] == '4']
r5= allSM_df.loc[allSM_df['run_num'] == '5']

r1src = sum(r1.key_resp_corr)/len(r1.key_resp_corr)
r2src = sum(r2.key_resp_corr)/len(r2.key_resp_corr)
r3src = sum(r3.key_resp_corr)/len(r3.key_resp_corr)
r4src = sum(r4.key_resp_corr)/len(r4.key_resp_corr)
r5src = sum(r5.key_resp_corr)/len(r5.key_resp_corr)

allSM_df.loc[allSM_df['run_num'] == '1', 'run_sm'] = r1src
allSM_df.loc[allSM_df['run_num'] == '2', 'run_sm'] = r2src
allSM_df.loc[allSM_df['run_num'] == '3', 'run_sm'] = r3src 
allSM_df.loc[allSM_df['run_num'] == '4', 'run_sm'] = r4src
allSM_df.loc[allSM_df['run_num'] == '5', 'run_sm'] = r5src

runs_src = [r1src, r2src, r3src, r4src, r5src]
#runs_src = [r1src, r2src, r3src] ### FOR MISSING RUNS- modify in the code above as well
print(runs_src)
allSM_df['allrun_src'] = str(runs_src)
# Out:
# [0.7037037037037037, 0.7037037037037037, 0.5925925925925926, 0.5277777777777778, 0.37962962962962965]

# %%
allSM_df
# Out:
#                 test_object                 correct_context tested_valence  \
# 3         new_obs/1_411.jpg  Scenes_selected/scene_069.jpeg         THREAT
# 4          new_obs/1_44.jpg  Scenes_selected/scene_061.jpeg           SAFE
# 5    new_obs/object_126.jpg   Scenes_selected/scene_009.jpg           SAFE
# 6           new_obs/1_3.jpg   Scenes_selected/scene_064.jpg           SAFE
# 7         new_obs/1_410.jpg   Scenes_selected/scene_045.jpg           SAFE
# ..                      ...                             ...            ...
# 105       new_obs/1_586.jpg   Scenes_selected/scene_015.jpg         THREAT
# 106  new_obs/object_607.jpg   Scenes_selected/scene_076.jpg           SAFE
# 107       new_obs/1_115.jpg   Scenes_selected/scene_084.jpg           SAFE
# 108       new_obs/1_296.jpg   Scenes_selected/scene_015.jpg         THREAT
# 109       new_obs/1_323.jpg   Scenes_selected/scene_035.jpg         THREAT
#
#     same_val opp_val                       same_foil  \
# 3     threat    safe   Scenes_selected/scene_024.jpg
# 4       safe  threat  Scenes_selected/scene_053.jpeg
# 5       safe  threat  Scenes_selected/scene_053.jpeg
# 6       safe  threat  Scenes_selected/scene_033.jpeg
# 7       safe  threat  Scenes_selected/scene_033.jpeg
# ..       ...     ...                             ...
# 105   threat    safe   Scenes_selected/scene_035.jpg
# 106     safe  threat   Scenes_selected/scene_036.jpg
# 107     safe  threat   Scenes_selected/scene_003.jpg
# 108   threat    safe   Scenes_selected/scene_025.jpg
# 109   threat    safe   Scenes_selected/scene_028.jpg
#
#                            opp_foil  test1_thisRepN  test1_thisTrialN  \
# 3    Scenes_selected/scene_061.jpeg             0.0               0.0
# 4     Scenes_selected/scene_049.jpg             0.0               1.0
# 5     Scenes_selected/scene_022.jpg             0.0               2.0
# 6     Scenes_selected/scene_049.jpg             0.0               3.0
# 7     Scenes_selected/scene_019.jpg             0.0               4.0
# ..                              ...             ...               ...
# 105   Scenes_selected/scene_079.jpg             0.0             103.0
# 106   Scenes_selected/scene_065.jpg             0.0             104.0
# 107   Scenes_selected/scene_085.jpg             0.0             105.0
# 108   Scenes_selected/scene_036.jpg             0.0             106.0
# 109   Scenes_selected/scene_036.jpg             0.0             107.0
#
#      test1_thisN  ...                     date      expName  psychopyVersion  \
# 3            0.0  ...  2023-03-08_11h07.26.065   src_mem.py         2022.2.4
# 4            1.0  ...  2023-03-08_11h07.26.065   src_mem.py         2022.2.4
# 5            2.0  ...  2023-03-08_11h07.26.065   src_mem.py         2022.2.4
# 6            3.0  ...  2023-03-08_11h07.26.065   src_mem.py         2022.2.4
# 7            4.0  ...  2023-03-08_11h07.26.065   src_mem.py         2022.2.4
# ..           ...  ...                      ...          ...              ...
# 105        103.0  ...  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4
# 106        104.0  ...  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4
# 107        105.0  ...  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4
# 108        106.0  ...  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4
# 109        107.0  ...  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4
#
#      frameRate  Unnamed: 46  run_num  Unnamed: 41 Unnamed: 42    run_sm  \
# 3    60.024982          NaN        1          NaN         NaN  0.703704
# 4    60.024982          NaN        1          NaN         NaN  0.703704
# 5    60.024982          NaN        1          NaN         NaN  0.703704
# 6    60.024982          NaN        1          NaN         NaN  0.703704
# 7    60.024982          NaN        1          NaN         NaN  0.703704
# ..         ...          ...      ...          ...         ...       ...
# 105  60.018102          NaN        5          NaN         NaN  0.379630
# 106  60.018102          NaN        5          NaN         NaN  0.379630
# 107  60.018102          NaN        5          NaN         NaN  0.379630
# 108  60.018102          NaN        5          NaN         NaN  0.379630
# 109  60.018102          NaN        5          NaN         NaN  0.379630
#
#                                             allrun_src
# 3    [0.7037037037037037, 0.7037037037037037, 0.592...
# 4    [0.7037037037037037, 0.7037037037037037, 0.592...
# 5    [0.7037037037037037, 0.7037037037037037, 0.592...
# 6    [0.7037037037037037, 0.7037037037037037, 0.592...
# 7    [0.7037037037037037, 0.7037037037037037, 0.592...
# ..                                                 ...
# 105  [0.7037037037037037, 0.7037037037037037, 0.592...
# 106  [0.7037037037037037, 0.7037037037037037, 0.592...
# 107  [0.7037037037037037, 0.7037037037037037, 0.592...
# 108  [0.7037037037037037, 0.7037037037037037, 0.592...
# 109  [0.7037037037037037, 0.7037037037037037, 0.592...
#
# [540 rows x 52 columns]

# %%
pt_dt = 'C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/'
os.makedirs(pt_dt, exist_ok=True)  
allSM_df.to_csv(pt_dt+"%s_ptSM_summary.csv"%pt_num, index = True, header = True )

# %%
allSM_df.columns
# Out:
# Index(['test_object', 'correct_context', 'tested_valence', 'same_val',
#        'opp_val', 'same_foil', 'opp_foil', 'test1_thisRepN',
#        'test1_thisTrialN', 'test1_thisN', 'test1_thisIndex', 'text_9_started',
#        'key_resp_6_started', 'key_resp_6_keys', 'key_resp_6_rt',
#        'text_11_started', 'key_resp_7_started', 'key_resp_7_keys',
#        'key_resp_7_rt', 'text_13_started', 'key_resp_8_started',
#        'key_resp_8_keys', 'key_resp_8_rt', 'text_12_started',
#        'text_12_stopped', 'text_started', 'object_cue_started',
#        'correct_cntxt_started', 'foil_same_started', 'foil_opp_started',
#        'key_resp_started', 'corrAns', 'samekey', 'oppkey', 'key_resp_keys',
#        'key_resp_corr', 'key_resp_rt', 'text_stopped', 'text_4_started',
#        'text_4_stopped', 'session', 'participant', 'date', 'expName',
#        'psychopyVersion', 'frameRate', 'Unnamed: 46', 'run_num', 'Unnamed: 41',
#        'Unnamed: 42', 'run_sm', 'allrun_src'],
#       dtype='object')

# %%
dt = pd.read_csv(pt_dt+"%s_ptSM_summary.csv"%pt_num)

# %%
dt
# Out:
#      Unnamed: 0             test_object                 correct_context  \
# 0             3       new_obs/1_411.jpg  Scenes_selected/scene_069.jpeg
# 1             4        new_obs/1_44.jpg  Scenes_selected/scene_061.jpeg
# 2             5  new_obs/object_126.jpg   Scenes_selected/scene_009.jpg
# 3             6         new_obs/1_3.jpg   Scenes_selected/scene_064.jpg
# 4             7       new_obs/1_410.jpg   Scenes_selected/scene_045.jpg
# ..          ...                     ...                             ...
# 535         105       new_obs/1_586.jpg   Scenes_selected/scene_015.jpg
# 536         106  new_obs/object_607.jpg   Scenes_selected/scene_076.jpg
# 537         107       new_obs/1_115.jpg   Scenes_selected/scene_084.jpg
# 538         108       new_obs/1_296.jpg   Scenes_selected/scene_015.jpg
# 539         109       new_obs/1_323.jpg   Scenes_selected/scene_035.jpg
#
#     tested_valence same_val opp_val                       same_foil  \
# 0           THREAT   threat    safe   Scenes_selected/scene_024.jpg
# 1             SAFE     safe  threat  Scenes_selected/scene_053.jpeg
# 2             SAFE     safe  threat  Scenes_selected/scene_053.jpeg
# 3             SAFE     safe  threat  Scenes_selected/scene_033.jpeg
# 4             SAFE     safe  threat  Scenes_selected/scene_033.jpeg
# ..             ...      ...     ...                             ...
# 535         THREAT   threat    safe   Scenes_selected/scene_035.jpg
# 536           SAFE     safe  threat   Scenes_selected/scene_036.jpg
# 537           SAFE     safe  threat   Scenes_selected/scene_003.jpg
# 538         THREAT   threat    safe   Scenes_selected/scene_025.jpg
# 539         THREAT   threat    safe   Scenes_selected/scene_028.jpg
#
#                            opp_foil  test1_thisRepN  test1_thisTrialN  ...  \
# 0    Scenes_selected/scene_061.jpeg             0.0               0.0  ...
# 1     Scenes_selected/scene_049.jpg             0.0               1.0  ...
# 2     Scenes_selected/scene_022.jpg             0.0               2.0  ...
# 3     Scenes_selected/scene_049.jpg             0.0               3.0  ...
# 4     Scenes_selected/scene_019.jpg             0.0               4.0  ...
# ..                              ...             ...               ...  ...
# 535   Scenes_selected/scene_079.jpg             0.0             103.0  ...
# 536   Scenes_selected/scene_065.jpg             0.0             104.0  ...
# 537   Scenes_selected/scene_085.jpg             0.0             105.0  ...
# 538   Scenes_selected/scene_036.jpg             0.0             106.0  ...
# 539   Scenes_selected/scene_036.jpg             0.0             107.0  ...
#
#                         date      expName  psychopyVersion  frameRate  \
# 0    2023-03-08_11h07.26.065   src_mem.py         2022.2.4  60.024982
# 1    2023-03-08_11h07.26.065   src_mem.py         2022.2.4  60.024982
# 2    2023-03-08_11h07.26.065   src_mem.py         2022.2.4  60.024982
# 3    2023-03-08_11h07.26.065   src_mem.py         2022.2.4  60.024982
# 4    2023-03-08_11h07.26.065   src_mem.py         2022.2.4  60.024982
# ..                       ...          ...              ...        ...
# 535  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4  60.018102
# 536  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4  60.018102
# 537  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4  60.018102
# 538  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4  60.018102
# 539  2023-03-08_12h25.03.803  src_mem5.py         2022.2.4  60.018102
#
#      Unnamed: 46  run_num  Unnamed: 41  Unnamed: 42    run_sm  \
# 0            NaN        1          NaN          NaN  0.703704
# 1            NaN        1          NaN          NaN  0.703704
# 2            NaN        1          NaN          NaN  0.703704
# 3            NaN        1          NaN          NaN  0.703704
# 4            NaN        1          NaN          NaN  0.703704
# ..           ...      ...          ...          ...       ...
# 535          NaN        5          NaN          NaN  0.379630
# 536          NaN        5          NaN          NaN  0.379630
# 537          NaN        5          NaN          NaN  0.379630
# 538          NaN        5          NaN          NaN  0.379630
# 539          NaN        5          NaN          NaN  0.379630
#
#                                             allrun_src
# 0    [0.7037037037037037, 0.7037037037037037, 0.592...
# 1    [0.7037037037037037, 0.7037037037037037, 0.592...
# 2    [0.7037037037037037, 0.7037037037037037, 0.592...
# 3    [0.7037037037037037, 0.7037037037037037, 0.592...
# 4    [0.7037037037037037, 0.7037037037037037, 0.592...
# ..                                                 ...
# 535  [0.7037037037037037, 0.7037037037037037, 0.592...
# 536  [0.7037037037037037, 0.7037037037037037, 0.592...
# 537  [0.7037037037037037, 0.7037037037037037, 0.592...
# 538  [0.7037037037037037, 0.7037037037037037, 0.592...
# 539  [0.7037037037037037, 0.7037037037037037, 0.592...
#
# [540 rows x 53 columns]

# %%
shrt_df = pd.DataFrame({ 
                        'tested_valence': dt.tested_valence,
                        'same_val': dt.same_val,
                        'opp_val':dt.opp_val,
                        'resp': dt.key_resp_keys,
                        'acc':dt.key_resp_corr,
                        'rt': dt.key_resp_rt, 
                        'runSM': dt.run_sm,
                        'allruns': dt.allrun_src})

# %%
#pt_SM = [] ### DELETE THIS LINE LATER!!
srcmem_corr = []
srcmem_incor = []
srcmem_miss = []

for index, row in shrt_df.iterrows():
    if shrt_df.acc[index] == 1:
        srcmem_corr.append(shrt_df.tested_valence[index])
SM = len(srcmem_corr)/len(shrt_df)
ls_runSM.append(shrt_df.allruns[3])
pt_SM.append(SM)

# %%
ls_runSM
# Out:
# ['[0.7870370370370371, 0.9074074074074074, 0.75, 0.7685185185185185, 0.8611111111111112]',
#  '[0.7037037037037037, 0.7037037037037037, 0.5925925925925926, 0.5277777777777778, 0.37962962962962965]']

# %%
SMdf = pd.DataFrame({'Mean_accuracy':pt_SM, 
                     'Runs_SM':ls_runSM})
SMdf.to_csv(pt_dt+"SMsummary.csv", index = True, header = True)

# %% [markdown]
# ## Graph

# %%
# %config InlineBackend.figure_format = 'retina'
plt.style.use('bmh')
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.grid'] = False
plt.rc('font', serif='Helvetica Neue') 
plt.rcParams['lines.markeredgecolor'] = 'w'
plt.rcParams['lines.markeredgewidth'] = 0.5
plt.rcParams['figure.figsize'] = [8, 6]
plt.rcParams['svg.fonttype']= 'none'
plt.rcParams.update({'font.size': 24})
plt.rc('xtick',labelsize=24)
plt.rc('ytick',labelsize=24)

# %%
sum_srcdt = pd.read_csv('C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary.csv')

# %%
sum_srcdt
# Out:
#    Unnamed: 0  Mean_accuracy  \
# 0           0       0.814815
# 1           1       0.581481
#
#                                              Runs_SM
# 0  [0.7870370370370371, 0.9074074074074074, 0.75,...
# 1  [0.7037037037037037, 0.7037037037037037, 0.592...

# %%
#sum_srcdt = SMdf
#sum_srcdt

# %%
#runs = [1,2,3]
runs = [1,2,3,4,5]
for index, row in sum_srcdt.iterrows():
    b = sum_srcdt.Runs_SM[index]
    g= b.replace('[','')
    h = g.replace(']','')
    res = [float(idx) for idx in h.split(', ')]
    plt.plot(runs, res, label = "participant_%s"%pt, linestyle="-.")
plt.xlabel("Runs")
plt.ylabel("Accuracy")
plt.xticks(runs)
plt.ylim(0,1)
plt.show()

# %%
b = sum_srcdt.Runs_SM[1]
g= b.replace('[','')
h = g.replace(']','')
res = [float(idx) for idx in h.split(', ')]
res
# Out:
# [0.6018518518518519,
#  0.49074074074074076,
#  0.3611111111111111,
#  0.3888888888888889,
#  0.5555555555555556]

# %%
type(res[1])
# Out:
# float

# %% [markdown]
# ### Christine's suggestions:
# 4s presentation + 1s ITI fix
# 3.5 presentation + 1.5s longer add in a response for imagination fixation
# break it down by the threat and safe conditions
# copresentation and disappearance
