# %% [markdown]
# # To run ONCE during session

# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
import math
from heapq import merge
from random import *
import scipy as sp
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt

# %%
subs = []
SC_all_SSwithin_bias = []
SC_all_TTwithin_bias = []

SC_all_SSacross_bias = []
SC_all_STacross_bias = []
SC_all_TSacross_bias = []
SC_all_TTacross_bias = []

# %%
sum_dir = '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/'
dir_ext = [f for f in listdir(sum_dir)]
pt_dir_lst = []
for i in dir_ext:
    pt_dir = sum_dir + i
    pt_dir_lst.append(pt_dir)

# %%
pt_dir_lst
# Out:
# ['/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/32.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/32.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/33.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/33.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/34.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/34.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/35.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/35.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/36.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/36.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/37.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/37.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/38.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/38.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/39.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/39.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/40.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/40.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/41.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/41.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/42.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/42.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/43.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/43.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/44.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/44.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/45.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/45.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/46.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/46.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/47.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/47.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/48.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/48.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/49.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/49.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/50.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/50.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/51.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/51.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/52.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/52.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/53.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/53.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/54.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/54.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/55.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/55.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/56.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/56.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/57.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/57.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/58.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/58.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/59.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/59.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/60.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/60.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/63.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/63.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/64.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/64.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/65.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/65.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/66.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/66.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/67.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/67.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/68.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/68.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/69.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/69.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/70.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/70.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/71.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/71.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/72.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/72.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/73.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/73.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/74.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/74.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/allsummary2.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/allsummary2_newbatch.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/binary_bias.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/binary_bias_sam.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/demographics_pt_5.16.2023.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/excluded',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/meeting_updates',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/new_batch',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/old',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/old2',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary_newbatch.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/src_controlled_bias']

# %%
tempdist_files = []
srcmem_files = []

for a in pt_dir_lst:
    if a[-4:] == '.csv' and '0_ptsummary' in a:
        tempdist_files.append(a)
    if a[-4:] == '.csv' and '0_ptSM_summary' in a:
        srcmem_files.append(a)

# %% [markdown]
# ## Edit # for each participant

# %%
pt_num = '74.0'

# %%
for t in tempdist_files:
    pt_num_tem = t[-18:-14]
    if pt_num_tem == pt_num:
        dt = pd.read_csv(t)
        condition = dt.condition
        objects1 =  list(dt.objects_pics)
        objects2 = list(dt.objects_pics2)
        key_resp = dt.key_resp_keys
        key_resp_rt = dt.key_resp_rt
        run_td = dt.run_num
        
for s in srcmem_files:
    pt_num_src = s[-21:-17]
    if pt_num_src == pt_num:
        sr = pd.read_csv(s)
        src_temp= []
        for index, row in sr.iterrows():
            obj = sr.test_object[index]
            if (obj in objects1) or (obj in objects2):
                src_temp.append(row)
                
src_temp_df = pd.DataFrame(src_temp)

# %%
src_corr = src_temp_df.loc[src_temp_df['key_resp_corr'] == 1]
src_corr
# Out:
#      Unnamed: 0             test_object                 correct_context  \
# 1             4       new_obs/1_114.jpg   Scenes_selected/scene_040.jpg
# 2             5       new_obs/1_424.jpg   Scenes_selected/scene_006.jpg
# 7            10       new_obs/1_508.jpg  Scenes_selected/scene_081.jpeg
# 10           13  new_obs/object_522.jpg   Scenes_selected/scene_060.jpg
# 11           14  new_obs/object_376.jpg   Scenes_selected/scene_068.jpg
# ..          ...                     ...                             ...
# 527          97       new_obs/1_187.jpg   Scenes_selected/scene_059.jpg
# 529          99        new_obs/1_45.jpg   Scenes_selected/scene_046.jpg
# 530         100       new_obs/1_301.jpg   Scenes_selected/scene_051.jpg
# 534         104  new_obs/object_374.jpg  Scenes_selected/scene_013.jpeg
# 535         105  new_obs/object_455.jpg  Scenes_selected/scene_097.jpeg
#
#     tested_valence same_val opp_val                       same_foil  \
# 1           THREAT   threat    safe   Scenes_selected/scene_043.jpg
# 2             SAFE     safe  threat   Scenes_selected/scene_009.jpg
# 7           THREAT   threat    safe   Scenes_selected/scene_024.jpg
# 10            SAFE     safe  threat   Scenes_selected/scene_015.jpg
# 11            SAFE     safe  threat   Scenes_selected/scene_003.jpg
# ..             ...      ...     ...                             ...
# 527           SAFE     safe  threat   Scenes_selected/scene_021.jpg
# 529           SAFE     safe  threat   Scenes_selected/scene_066.jpg
# 530         THREAT   threat    safe   Scenes_selected/scene_088.jpg
# 534         THREAT   threat    safe  Scenes_selected/scene_097.jpeg
# 535         THREAT   threat    safe   Scenes_selected/scene_062.jpg
#
#                            opp_foil  test1_thisRepN  test1_thisTrialN  ...  \
# 1     Scenes_selected/scene_064.jpg             0.0               1.0  ...
# 2     Scenes_selected/scene_040.jpg             0.0               2.0  ...
# 7     Scenes_selected/scene_006.jpg             0.0               7.0  ...
# 10    Scenes_selected/scene_054.jpg             0.0              10.0  ...
# 11    Scenes_selected/scene_004.jpg             0.0              11.0  ...
# ..                              ...             ...               ...  ...
# 527   Scenes_selected/scene_088.jpg             0.0              95.0  ...
# 529  Scenes_selected/scene_013.jpeg             0.0              97.0  ...
# 530   Scenes_selected/scene_079.jpg             0.0              98.0  ...
# 534   Scenes_selected/scene_079.jpg             0.0             102.0  ...
# 535   Scenes_selected/scene_066.jpg             0.0             103.0  ...
#
#          expName  psychopyVersion  frameRate  run_num  Unnamed: 41  \
# 1     src_mem.py         2022.2.1  60.028514        1          NaN
# 2     src_mem.py         2022.2.1  60.028514        1          NaN
# 7     src_mem.py         2022.2.1  60.028514        1          NaN
# 10    src_mem.py         2022.2.1  60.028514        1          NaN
# 11    src_mem.py         2022.2.1  60.028514        1          NaN
# ..           ...              ...        ...      ...          ...
# 527  src_mem5.py         2022.2.1  59.820526        5          NaN
# 529  src_mem5.py         2022.2.1  59.820526        5          NaN
# 530  src_mem5.py         2022.2.1  59.820526        5          NaN
# 534  src_mem5.py         2022.2.1  59.820526        5          NaN
# 535  src_mem5.py         2022.2.1  59.820526        5          NaN
#
#      Unnamed: 40    run_sm                                         allrun_src  \
# 1            NaN  0.759259  [0.7592592592592593, 0.8703703703703703, 0.796...
# 2            NaN  0.759259  [0.7592592592592593, 0.8703703703703703, 0.796...
# 7            NaN  0.759259  [0.7592592592592593, 0.8703703703703703, 0.796...
# 10           NaN  0.759259  [0.7592592592592593, 0.8703703703703703, 0.796...
# 11           NaN  0.759259  [0.7592592592592593, 0.8703703703703703, 0.796...
# ..           ...       ...                                                ...
# 527          NaN  0.490741  [0.7592592592592593, 0.8703703703703703, 0.796...
# 529          NaN  0.490741  [0.7592592592592593, 0.8703703703703703, 0.796...
# 530          NaN  0.490741  [0.7592592592592593, 0.8703703703703703, 0.796...
# 534          NaN  0.490741  [0.7592592592592593, 0.8703703703703703, 0.796...
# 535          NaN  0.490741  [0.7592592592592593, 0.8703703703703703, 0.796...
#
#                                            safe_runsSM  \
# 1    [0.7962962962962963, 0.8888888888888888, 0.796...
# 2    [0.7962962962962963, 0.8888888888888888, 0.796...
# 7    [0.7962962962962963, 0.8888888888888888, 0.796...
# 10   [0.7962962962962963, 0.8888888888888888, 0.796...
# 11   [0.7962962962962963, 0.8888888888888888, 0.796...
# ..                                                 ...
# 527  [0.7962962962962963, 0.8888888888888888, 0.796...
# 529  [0.7962962962962963, 0.8888888888888888, 0.796...
# 530  [0.7962962962962963, 0.8888888888888888, 0.796...
# 534  [0.7962962962962963, 0.8888888888888888, 0.796...
# 535  [0.7962962962962963, 0.8888888888888888, 0.796...
#
#                                          threat_runsSM
# 1    [0.7222222222222222, 0.8518518518518519, 0.796...
# 2    [0.7222222222222222, 0.8518518518518519, 0.796...
# 7    [0.7222222222222222, 0.8518518518518519, 0.796...
# 10   [0.7222222222222222, 0.8518518518518519, 0.796...
# 11   [0.7222222222222222, 0.8518518518518519, 0.796...
# ..                                                 ...
# 527  [0.7222222222222222, 0.8518518518518519, 0.796...
# 529  [0.7222222222222222, 0.8518518518518519, 0.796...
# 530  [0.7222222222222222, 0.8518518518518519, 0.796...
# 534  [0.7222222222222222, 0.8518518518518519, 0.796...
# 535  [0.7222222222222222, 0.8518518518518519, 0.796...
#
# [239 rows x 54 columns]

# %%
mrgd = dt.merge(src_temp_df,how='left', left_on='objects_pics', right_on='test_object')
mrgd_dts = 'C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/src_controlled_bias/'
os.makedirs(mrgd_dts, exist_ok=True)  
mrgd.to_csv(mrgd_dts+"%s_MRGD_srctemp.csv"%pt_num, index = True, header = True )

# %%
shrt_df = pd.DataFrame({ 
                        'contxt1': mrgd.context_type,
                        'contxt2': mrgd.context_type2,
                        'context_shock':mrgd.context_shock,
                        'context_shock2':mrgd.context_shock2,
                        'cond1': mrgd.condition,
                        'cond2': mrgd.condition2,
                        'resp_temp': mrgd.key_resp_keys_x,
                        'rt_temp': mrgd.key_resp_rt_x,
                        'resp_acc': mrgd.key_resp_corr,
                        'resp_src': mrgd.key_resp_keys_y,
                        'rt_src': mrgd.key_resp_rt_y})

# %%
within_TT = []
within_SS = []

across_TT = []
across_TS = []
across_ST = []
across_SS = []

rt_within_TT = []
rt_within_SS = []

rt_across_TT = []
rt_across_TS = []
rt_across_ST = []
rt_across_SS = []

for index, row in shrt_df.iterrows():
    resp_dt = shrt_df.resp_temp
    resp_rt = shrt_df.rt_temp
    if shrt_df.cond1[index] == 'within_threat1' and shrt_df.cond2[index] == 'within_threat2' and shrt_df.resp_acc[index] == 1:
        within_TT.append(resp_dt[index])
        rt_within_TT.append(resp_rt[index])
        
    if shrt_df.cond1[index] == 'within_safe1' and shrt_df.cond2[index] == 'within_safe2' and shrt_df.resp_acc[index] == 1:
        within_SS.append(resp_dt[index])
        rt_within_SS.append(resp_rt[index])
        
for index, row in shrt_df.iterrows():
    resp_dt = shrt_df.resp_temp
    resp_rt = shrt_df.rt_temp
    if shrt_df.cond1[index] == 'across_threat1' and shrt_df.cond2[index] == 'across_threat2' and shrt_df.context_shock[index] != 'prior' and shrt_df.context_shock2[index] != 'post' and shrt_df.resp_acc[index] == 1:
        across_TT.append(resp_dt[index])
        rt_across_TT.append(resp_rt[index])
        
    if shrt_df.cond1[index] == 'across_threat1' and shrt_df.cond2[index] == 'across_safe2' and shrt_df.context_shock[index] != 'prior' and shrt_df.context_shock2[index] != 'post' and shrt_df.resp_acc[index] == 1:
        across_TS.append(resp_dt[index])
        rt_across_TS.append(resp_rt[index])
        
    if shrt_df.cond1[index] == 'across_safe1' and shrt_df.cond2[index] == 'across_threat2' and shrt_df.context_shock[index] != 'prior' and shrt_df.context_shock2[index] != 'post' and shrt_df.resp_acc[index] == 1:
        across_ST.append(resp_dt[index])
        rt_across_ST.append(resp_rt[index])
    
    if shrt_df.cond1[index] == 'across_safe1' and shrt_df.cond2[index] == 'across_safe2' and shrt_df.context_shock[index] != 'prior' and shrt_df.context_shock2[index] != 'post' and shrt_df.resp_acc[index] == 1:
        across_SS.append(resp_dt[index])
        rt_across_SS.append(resp_rt[index])

# %%
SSwithin_close = []
SSwithin_far = []

TTwithin_close = []
TTwithin_far = []

for a in within_SS:
    if a == 1 or a == 2:
        SSwithin_close.append(a)
    if a == 3 or a == 4:
        SSwithin_far.append(a)
        
for a in within_TT:
    if a == 1 or a == 2:
        TTwithin_close.append(a)
    if a == 3 or a == 4:
        TTwithin_far.append(a)

# %%
SSacross_close = []
SSacross_far = []

STacross_close = []
STacross_far = []

TSacross_close = []
TSacross_far = []

TTacross_close = []
TTacross_far = []

for c in across_SS:
    if c == 1 or c == 2:
        SSacross_close.append(c)
    if c == 3 or c == 4:
        SSacross_far.append(c)
        
for c in across_TT:
    if c == 1 or c == 2:
        TTacross_close.append(c)
    if c == 3 or c == 4:
        TTacross_far.append(c)
        
for c in across_ST:
    if c == 1 or c == 2:
        STacross_close.append(c)
    if c == 3 or c == 4:
        STacross_far.append(c)
        
for c in across_TS:
    if c == 1 or c == 2:
        TSacross_close.append(c)
    if c == 3 or c == 4:
        TSacross_far.append(c)

# %%
SSwithin_bias = (len(SSwithin_close)-len(SSwithin_far))/(len(SSwithin_close)+len(SSwithin_far))
SC_all_SSwithin_bias.append(SSwithin_bias)
TTwithin_bias = (len(TTwithin_close)-len(TTwithin_far))/(len(TTwithin_close)+len(TTwithin_far))
SC_all_TTwithin_bias.append(TTwithin_bias)

SSacross_bias = (len(SSacross_close)-len(SSacross_far))/(len(SSacross_close)+len(SSacross_far))
SC_all_SSacross_bias.append(SSacross_bias)
STacross_bias = (len(STacross_close)-len(STacross_far))/(len(STacross_close)+len(STacross_far))
SC_all_STacross_bias.append(STacross_bias)
TSacross_bias = (len(TSacross_close)-len(TSacross_far))/(len(TSacross_close)+len(TSacross_far))
SC_all_TSacross_bias.append(TSacross_bias)
TTacross_bias = (len(TTacross_close)-len(TTacross_far))/(len(TTacross_close)+len(TTacross_far))
SC_all_TTacross_bias.append(TTacross_bias)

subs.append(pt_num)

# %%
x = ['Safe', 'Threat']
y = [SSwithin_bias, TTwithin_bias]
plt.bar(x, y, width=0.8, bottom=None, color = ['grey', 'purple'], align='center', data=None)
plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(fontsize = "x-large")
plt.ylabel("Close-bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.title("%s_Within context temporal bias"%pt_num, fontsize = "x-large")
# Out:
# Text(0.5, 1.0, '74.0_Within context temporal bias')

# %%
x = ['S-S', 'S-T', 'T-S', 'T-T']
y = [SSacross_bias, STacross_bias, TSacross_bias, TTacross_bias]
plt.bar(x, y, width=0.8, bottom=None, color = ['green', 'limegreen', 'gold','crimson'], align='center', data=None)
plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(fontsize = "x-large")
plt.ylabel("Close-bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.title("%s_Across context temporal bias"%pt_num, fontsize = "x-large")
# Out:
# Text(0.5, 1.0, '74.0_Across context temporal bias')

# %%
x = ['Safe', 'Threat','S-S', 'S-T', 'T-S', 'T-T']
y = [np.mean(SC_all_SSwithin_bias), np.mean(SC_all_TTwithin_bias), np.mean(SC_all_SSacross_bias), np.mean(SC_all_STacross_bias), np.mean(SC_all_TSacross_bias), np.mean(SC_all_TTacross_bias)]
plt.bar(x, y, width=0.8, bottom=None, color = ['grey', 'purple','green', 'limegreen', 'gold','crimson'], align='center', data=None)
plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(fontsize = "x-large")
plt.ylabel("Close-bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.title("All pts_Across context temporal bias", fontsize = "x-large")
# Out:
# Text(0.5, 1.0, 'All pts_Across context temporal bias')

# %%
labels = ['Safe', 'Threat', 'S-S','S-T', 'T-S', 'T-T']
data = [SC_all_SSwithin_bias, SC_all_TTwithin_bias, SC_all_SSacross_bias, SC_all_STacross_bias, SC_all_TSacross_bias, SC_all_TTacross_bias]
colors = ['grey', 'purple','green', 'limegreen', 'gold','crimson']
sns.stripplot(data = data, s=10, linewidth=1, palette=colors)

plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(np.arange(6), labels, fontsize = "x-large")
plt.ylabel("Close-bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.title("All pts All context bias", fontsize = "x-large")
plt.show()

# %%
summarydf = pd.DataFrame({"Participant": subs,
                          "Safe_within_bias":SC_all_SSwithin_bias,
                          "Threat_within_bias":SC_all_TTwithin_bias,
                         "SS_across_bias":SC_all_SSacross_bias,
                         "ST_across_bias":SC_all_STacross_bias,
                         "TS_across_bias":SC_all_TSacross_bias,
                         "TT_across_bias":SC_all_TTacross_bias})
summarydf.to_csv(mrgd_dts+"allSC_bias_newbatch.csv", index = True, header = True )

# %%
summarydf
# Out:
#    Participant  Safe_within_bias  Threat_within_bias  SS_across_bias  \
# 0         32.0          0.560976            0.578947       -0.263158
# 1         33.0         -0.037037            0.040000       -0.200000
# 2         34.0          0.393939            0.235294        0.285714
# 3         35.0          0.151515            0.393939       -0.692308
# 4         36.0         -0.024390            0.371429       -0.111111
# 5         37.0          0.411765            0.454545       -0.500000
# 6         38.0          0.179487            0.567568       -0.333333
# 7         39.0          0.538462            0.241379       -0.166667
# 8         40.0          0.083333            0.000000        0.090909
# 9         41.0         -0.076923           -0.125000        0.000000
# 10        42.0          0.904762            0.809524        0.000000
# 11        43.0          0.151515            0.130435       -0.230769
# 12        44.0         -0.266667            0.368421       -0.333333
# 13        45.0         -0.161290            0.176471       -0.230769
# 14        46.0          0.500000            0.027027       -0.142857
# 15        47.0          0.111111            0.466667        0.230769
# 16        48.0          0.105263            0.025641        0.333333
# 17        49.0          0.421053            0.600000       -0.384615
# 18        50.0          0.166667           -0.222222       -0.600000
# 19        51.0          0.523810            0.297297        0.000000
# 20        52.0         -0.172414            0.333333        0.818182
# 21        53.0          0.125000            0.419355       -0.384615
# 22        54.0          0.277778            0.257143       -0.222222
# 23        55.0         -0.360000           -0.473684       -0.400000
# 24        56.0          0.414634            0.589744        0.066667
# 25        57.0          0.290323            0.428571        0.333333
# 26        58.0          0.315789            0.200000       -0.666667
# 27        59.0          0.666667            0.906977       -0.263158
# 28        60.0          0.314286            0.300000        0.052632
# 29        63.0         -0.272727           -0.111111       -0.636364
# 30        64.0          0.538462            0.641026       -0.777778
# 31        65.0          0.285714            0.272727       -0.090909
# 32        66.0          0.255814            0.400000       -0.384615
# 33        67.0         -0.058824            0.400000        0.600000
# 34        68.0          0.500000            0.428571        0.263158
# 35        69.0         -0.083333           -0.238095        0.090909
# 36        70.0         -0.444444           -0.058824        0.090909
# 37        71.0         -0.333333           -0.230769       -0.111111
# 38        72.0          0.512195            0.500000       -0.625000
# 39        73.0         -0.117647           -0.034483       -0.333333
# 40        74.0          0.294118            0.655172       -0.666667
#
#     ST_across_bias  TS_across_bias  TT_across_bias
# 0        -0.230769       -0.375000       -0.375000
# 1        -0.500000        0.142857        0.000000
# 2         0.166667        0.000000        0.000000
# 3        -0.647059       -0.200000       -0.818182
# 4        -0.692308       -0.333333        0.285714
# 5        -0.230769       -0.857143       -0.111111
# 6        -0.222222       -0.157895       -0.529412
# 7         0.600000        0.400000       -0.125000
# 8        -0.333333       -0.200000        0.333333
# 9         0.333333        0.000000       -0.333333
# 10       -0.444444       -0.222222       -0.333333
# 11       -0.090909       -0.600000       -0.142857
# 12       -0.200000       -0.200000        0.090909
# 13       -0.176471       -0.285714        0.000000
# 14        0.285714       -0.384615       -0.428571
# 15       -0.090909       -0.090909        0.090909
# 16       -0.285714       -0.200000       -0.692308
# 17       -0.500000       -0.111111       -0.142857
# 18       -0.428571       -0.571429        0.000000
# 19        0.375000        0.066667        0.000000
# 20       -0.400000        0.000000        0.200000
# 21       -0.600000        0.000000        0.200000
# 22        0.066667        0.250000        0.076923
# 23       -0.200000        0.111111       -0.111111
# 24       -0.555556       -0.857143       -0.777778
# 25        0.454545        0.111111       -0.142857
# 26       -0.538462       -0.692308       -0.714286
# 27       -0.666667       -0.578947       -0.333333
# 28       -0.333333       -0.375000       -0.733333
# 29        0.200000       -0.250000       -0.600000
# 30       -0.529412       -0.578947       -0.222222
# 31        0.272727        0.454545        0.111111
# 32       -0.411765       -0.200000       -0.500000
# 33        0.000000       -0.400000        0.272727
# 34       -0.230769       -0.333333        0.000000
# 35       -0.428571       -0.166667       -0.333333
# 36        0.142857       -0.111111       -0.600000
# 37       -0.600000        0.000000       -0.111111
# 38       -0.875000       -0.625000       -0.625000
# 39       -0.538462       -0.454545       -0.200000
# 40       -0.384615       -0.636364       -0.466667

# %% [markdown]
# # predicted results

# %%
x = ['Safe', 'Threat','S-S', 'S-T', 'T-S', 'T-T']
y = [0.4, -0.2, -0.1, -0.4, -0.2, 0.3]
plt.bar(x, y, width=0.8, bottom=None, color = ['grey', 'purple','green', 'limegreen', 'gold','crimson'], align='center', data=None)
plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(fontsize = "x-large")
plt.ylabel("'Close'- 'Far' bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("Predicted Temporal Bias", fontsize = "x-large")
# Out:
# Text(0.5, 1.0, 'Predicted Temporal Bias')

# %% [markdown]
# # group results

# %%
res_csv = pd.read_csv('/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/src_controlled_bias/allSC_bias_newbatch.csv')

# %%
res_csv
# Out:
#     Unnamed: 0  Participant  Safe_within_bias  Threat_within_bias  \
# 0            0         32.0          0.560976            0.578947
# 1            1         33.0         -0.037037            0.040000
# 2            2         34.0          0.393939            0.235294
# 3            3         35.0          0.151515            0.393939
# 4            4         36.0         -0.024390            0.371429
# 5            5         37.0          0.411765            0.454545
# 6            6         38.0          0.179487            0.567568
# 7            7         39.0          0.538462            0.241379
# 8            8         40.0          0.083333            0.000000
# 9            9         41.0         -0.076923           -0.125000
# 10          10         42.0          0.904762            0.809524
# 11          11         43.0          0.151515            0.130435
# 12          12         44.0         -0.266667            0.368421
# 13          13         45.0         -0.161290            0.176471
# 14          14         46.0          0.500000            0.027027
# 15          15         47.0          0.111111            0.466667
# 16          16         48.0          0.105263            0.025641
# 17          17         49.0          0.421053            0.600000
# 18          18         50.0          0.166667           -0.222222
# 19          19         51.0          0.523810            0.297297
# 20          20         52.0         -0.172414            0.333333
# 21          21         53.0          0.125000            0.419355
# 22          22         54.0          0.277778            0.257143
# 23          23         55.0         -0.360000           -0.473684
# 24          24         56.0          0.414634            0.589744
# 25          25         57.0          0.290323            0.428571
# 26          26         58.0          0.315789            0.200000
# 27          27         59.0          0.666667            0.906977
# 28          28         60.0          0.314286            0.300000
# 29          29         63.0         -0.272727           -0.111111
# 30          30         64.0          0.538462            0.641026
# 31          31         65.0          0.285714            0.272727
# 32          32         66.0          0.255814            0.400000
# 33          33         67.0         -0.058824            0.400000
# 34          34         68.0          0.500000            0.428571
# 35          35         69.0         -0.083333           -0.238095
# 36          36         70.0         -0.444444           -0.058824
# 37          37         71.0         -0.333333           -0.230769
# 38          38         72.0          0.512195            0.500000
# 39          39         73.0         -0.117647           -0.034483
# 40          40         74.0          0.294118            0.655172
#
#     SS_across_bias  ST_across_bias  TS_across_bias  TT_across_bias
# 0        -0.263158       -0.230769       -0.375000       -0.375000
# 1        -0.200000       -0.500000        0.142857        0.000000
# 2         0.285714        0.166667        0.000000        0.000000
# 3        -0.692308       -0.647059       -0.200000       -0.818182
# 4        -0.111111       -0.692308       -0.333333        0.285714
# 5        -0.500000       -0.230769       -0.857143       -0.111111
# 6        -0.333333       -0.222222       -0.157895       -0.529412
# 7        -0.166667        0.600000        0.400000       -0.125000
# 8         0.090909       -0.333333       -0.200000        0.333333
# 9         0.000000        0.333333        0.000000       -0.333333
# 10        0.000000       -0.444444       -0.222222       -0.333333
# 11       -0.230769       -0.090909       -0.600000       -0.142857
# 12       -0.333333       -0.200000       -0.200000        0.090909
# 13       -0.230769       -0.176471       -0.285714        0.000000
# 14       -0.142857        0.285714       -0.384615       -0.428571
# 15        0.230769       -0.090909       -0.090909        0.090909
# 16        0.333333       -0.285714       -0.200000       -0.692308
# 17       -0.384615       -0.500000       -0.111111       -0.142857
# 18       -0.600000       -0.428571       -0.571429        0.000000
# 19        0.000000        0.375000        0.066667        0.000000
# 20        0.818182       -0.400000        0.000000        0.200000
# 21       -0.384615       -0.600000        0.000000        0.200000
# 22       -0.222222        0.066667        0.250000        0.076923
# 23       -0.400000       -0.200000        0.111111       -0.111111
# 24        0.066667       -0.555556       -0.857143       -0.777778
# 25        0.333333        0.454545        0.111111       -0.142857
# 26       -0.666667       -0.538462       -0.692308       -0.714286
# 27       -0.263158       -0.666667       -0.578947       -0.333333
# 28        0.052632       -0.333333       -0.375000       -0.733333
# 29       -0.636364        0.200000       -0.250000       -0.600000
# 30       -0.777778       -0.529412       -0.578947       -0.222222
# 31       -0.090909        0.272727        0.454545        0.111111
# 32       -0.384615       -0.411765       -0.200000       -0.500000
# 33        0.600000        0.000000       -0.400000        0.272727
# 34        0.263158       -0.230769       -0.333333        0.000000
# 35        0.090909       -0.428571       -0.166667       -0.333333
# 36        0.090909        0.142857       -0.111111       -0.600000
# 37       -0.111111       -0.600000        0.000000       -0.111111
# 38       -0.625000       -0.875000       -0.625000       -0.625000
# 39       -0.333333       -0.538462       -0.454545       -0.200000
# 40       -0.666667       -0.384615       -0.636364       -0.466667

# %%
labels = ['Safe', 'Threat', 'S-S','S-T', 'T-S', 'T-T']
data = [res_csv.Safe_within_bias, res_csv.Threat_within_bias, res_csv.SS_across_bias, res_csv.ST_across_bias, res_csv.TS_across_bias, res_csv.TT_across_bias]
colors = ['grey', 'purple','green', 'limegreen', 'gold','crimson']
sns.stripplot(data = data, s=10, linewidth=1, palette=colors)

plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(np.arange(6), labels, fontsize = "x-large")
plt.ylabel("'Close'- 'Far' bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All pts All context bias", fontsize = "x-large")
plt.show()

# %%
x = ['Safe', 'Threat','S-S', 'S-T', 'T-S', 'T-T']
y = [np.mean(res_csv.Safe_within_bias), np.mean(res_csv.Threat_within_bias), np.mean(res_csv.SS_across_bias), np.mean(res_csv.ST_across_bias), np.mean(res_csv.TS_across_bias), np.mean(res_csv.TT_across_bias)]
totalpts = len(res_csv)
sem = [stats.sem(res_csv.Safe_within_bias), stats.sem(res_csv.Threat_within_bias), stats.sem(res_csv.SS_across_bias), stats.sem(res_csv.ST_across_bias), stats.sem(res_csv.TS_across_bias), stats.sem(res_csv.TT_across_bias)]
plt.bar(x, y, width=0.8, bottom=None, color = ['grey', 'purple','green', 'limegreen', 'gold','crimson'], align='center', data=None, yerr = sem, error_kw=dict(elinewidth=2,ecolor='black'))
plt.ylim(-1, 1)
plt.xlabel("Context", fontsize = "x-large")
plt.xticks(fontsize = "x-large")
plt.ylabel("'Close'- 'Far' bias", fontsize = "x-large")
plt.yticks(fontsize = "x-large")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')
plt.title("All participants (N = %s) temporal bias"%totalpts, fontsize = "x-large")
# Out:
# Text(0.5, 1.0, 'All participants (N = 41) temporal bias')
