# %% [markdown]
# ## Only to run once during one session

# %%
## importing all libraries and dependencies
import pandas as pd
import numpy as np
import os
from os import listdir
import glob
from os.path import isfile, join
import shutil
import PIL
from PIL import Image
import random
import math
from heapq import merge
from random import *
import scipy as sp
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt

# %%
opp_SM = []
sam_SM = []
S_sam_SM = []
T_sam_SM = []
S_opp_SM = []
T_opp_SM = []

# %%
sum_dir = '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/'
dir_ext = [f for f in listdir(sum_dir)]
pt_dir_lst = []
for i in dir_ext:
    pt_dir = sum_dir + i
    pt_dir_lst.append(pt_dir)

# %%
pt_dir_lst
# Out:
# ['/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/32.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/32.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/33.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/33.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/33.0_tstMRGDsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/34.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/34.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/35.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/35.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/36.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/36.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/37.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/37.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/38.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/38.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/39.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/39.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/40.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/40.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/41.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/41.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/42.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/42.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/43.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/43.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/44.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/44.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/45.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/45.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/46.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/46.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/47.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/47.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/48.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/48.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/49.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/49.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/50.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/50.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/51.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/51.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/52.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/52.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/53.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/53.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/54.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/54.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/55.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/55.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/56.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/56.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/57.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/57.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/58.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/58.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/59.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/59.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/60.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/60.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/61.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/62.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/63.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/63.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/64.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/64.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/65.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/65.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/66.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/66.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/67.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/67.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/68.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/68.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/69.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/69.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/70.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/70.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/71.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/71.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/72.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/72.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/73.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/73.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/74.0_ptSM_summary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/74.0_ptsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/allsummary2.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/allsummary2_newbatch.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/binary_bias.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/binary_bias_sam.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/demographics_pt_5.16.2023.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/meeting_updates',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/new_batch',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/old',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/old2',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary_newbatch.csv',
#  '/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/src_controlled_bias']

# %%
tempdist_files = []
srcmem_files = []

for a in pt_dir_lst:
    if a[-4:] == '.csv' and '0_ptsummary' in a:
        tempdist_files.append(a)
    if a[-4:] == '.csv' and '0_ptSM_summary' in a:
        srcmem_files.append(a)

# %% [markdown]
# ## For each participant

# %%
pt_num = '56.0'
for s in srcmem_files:
    pt_num_src = s[-21:-17]
    if pt_num_src == pt_num:
        sr = pd.read_csv(s)
                
src_df = pd.DataFrame(sr)
src_incorr = src_df.loc[src_df['key_resp_corr'] == 0]

# %%
src_incorr.key_resp_keys
# Out:
# 10     3.0
# 13     2.0
# 36     1.0
# 39     1.0
# 54     2.0
#       ...
# 524    3.0
# 527    2.0
# 529    1.0
# 530    3.0
# 538    1.0
# Name: key_resp_keys, Length: 76, dtype: float64

# %%
for index, row in src_incorr.iterrows():
    if src_incorr.key_resp_keys[index] == src_incorr.samekey[index] and src_incorr.tested_valence[index] == 'SAFE':
        sam_SM.append(row)
        S_sam_SM.append(row)
    if src_incorr.key_resp_keys[index] == src_incorr.samekey[index] and src_incorr.tested_valence[index] == 'THREAT':
        sam_SM.append(row)
        T_sam_SM.append(row)
    if src_incorr.key_resp_keys[index] == src_incorr.oppkey[index] and src_incorr.tested_valence[index] == 'SAFE':
        opp_SM.append(row)
        S_opp_SM.append(row)
    if src_incorr.key_resp_keys[index] == src_incorr.oppkey[index] and src_incorr.tested_valence[index] == 'SAFE':
        opp_SM.append(row)
        S_opp_SM.append(row)

# %%
print(len(sam_SM))
print(len(opp_SM))
# Out:
# 42
# 38

# %%
print(len(S_sam_SM))
print(len(T_sam_SM))
print(len(S_opp_SM))
print(len(T_opp_SM))
# Out:
# 23
# 19
# 38
# 0
# 42

# %%
SMdf_extra = pd.DataFrame({'Mean_accuracy':pt_SM,
                     'Mean_safe': safe_pt_SM,
                     'Mean_threat': threat_pt_SM,
                     'Runs_SM':ls_runSM,
                    'Safe_runsSM': safe_ls_runSM,
                    'Threat_runsSM': threat_ls_runSM})
SMdf.to_csv(pt_dt+"SMsummary_newbatch.csv", index = True, header = True)
SMdf

# %%
Sr1= (allSM_df['run_num'] == '1') & (allSM_df['tested_valence'] == 'SAFE')
Sr1 = allSM_df[Sr1]
Sr2= (allSM_df['run_num'] == '2') & (allSM_df['tested_valence'] == 'SAFE')
Sr2 = allSM_df[Sr2]
Sr3= (allSM_df['run_num'] == '3') & (allSM_df['tested_valence'] == 'SAFE')
Sr3 = allSM_df[Sr3]
Sr4= (allSM_df['run_num'] == '4') & (allSM_df['tested_valence'] == 'SAFE')
Sr4 = allSM_df[Sr4]
Sr5= (allSM_df['run_num'] == '5') & (allSM_df['tested_valence'] == 'SAFE')
Sr5 = allSM_df[Sr5]

Tr1= (allSM_df['run_num'] == '1') & (allSM_df['tested_valence'] == 'THREAT')
Tr1 = allSM_df[Tr1]
Tr2= (allSM_df['run_num'] == '2') & (allSM_df['tested_valence'] == 'THREAT')
Tr2 = allSM_df[Tr2]
Tr3= (allSM_df['run_num'] == '3') & (allSM_df['tested_valence'] == 'THREAT')
Tr3 = allSM_df[Tr3]
Tr4= (allSM_df['run_num'] == '4') & (allSM_df['tested_valence'] == 'THREAT')
Tr4 = allSM_df[Tr4]
Tr5= (allSM_df['run_num'] == '5') & (allSM_df['tested_valence'] == 'THREAT')
Tr5 = allSM_df[Tr5]

#Sr1src = sum(Sr1.key_resp_corr)/len(Sr1.key_resp_corr)
#Sr2src = sum(Sr2.key_resp_corr)/len(Sr2.key_resp_corr)
#Sr3src = sum(Sr3.key_resp_corr)/len(Sr3.key_resp_corr)
#Sr4src = sum(Sr4.key_resp_corr)/len(Sr4.key_resp_corr)
#Sr5src = sum(Sr5.key_resp_corr)/len(Sr5.key_resp_corr)

#Tr1src = sum(Tr1.key_resp_corr)/len(Tr1.key_resp_corr)
#Tr2src = sum(Tr2.key_resp_corr)/len(Tr2.key_resp_corr)
#Tr3src = sum(Tr3.key_resp_corr)/len(Tr3.key_resp_corr)
#Tr4src = sum(Tr4.key_resp_corr)/len(Tr4.key_resp_corr)
#Tr5src = sum(Tr5.key_resp_corr)/len(Tr5.key_resp_corr)

# %%
for a in Sr1:
    if
# Out:
#                 test_object                 correct_context tested_valence  \
# 3         new_obs/1_137.jpg   Scenes_selected/scene_068.jpg         THREAT
# 4         new_obs/1_362.jpg  Scenes_selected/scene_098.jpeg         THREAT
# 6    new_obs/object_005.jpg   Scenes_selected/scene_038.jpg         THREAT
# 7         new_obs/1_191.jpg   Scenes_selected/scene_038.jpg         THREAT
# 9         new_obs/1_242.jpg   Scenes_selected/scene_075.jpg         THREAT
# 10         new_obs/1_39.jpg  Scenes_selected/scene_069.jpeg         THREAT
# 11        new_obs/1_532.jpg  Scenes_selected/scene_098.jpeg         THREAT
#
# 97        new_obs/1_409.jpg   Scenes_selected/scene_086.jpg         THREAT
# 99        new_obs/1_135.jpg   Scenes_selected/scene_058.jpg         THREAT
# 101  new_obs/object_266.jpg   Scenes_selected/scene_086.jpg         THREAT
# 102       new_obs/1_405.jpg  Scenes_selected/scene_069.jpeg         THREAT
# 103       new_obs/1_312.jpg   Scenes_selected/scene_083.jpg         THREAT
# 104       new_obs/1_561.jpg   Scenes_selected/scene_068.jpg         THREAT
# 109       new_obs/1_351.jpg  Scenes_selected/scene_069.jpeg         THREAT
#
#     same_val opp_val                       same_foil  \
# 3     threat    safe  Scenes_selected/scene_098.jpeg
# 4     threat    safe   Scenes_selected/scene_058.jpg
# 6     threat    safe  Scenes_selected/scene_069.jpeg
# 7     threat    safe   Scenes_selected/scene_086.jpg
# 9     threat    safe  Scenes_selected/scene_098.jpeg
# 10    threat    safe   Scenes_selected/scene_058.jpg
# 11    threat    safe   Scenes_selected/scene_083.jpg
# 12    threat    safe   Scenes_selected/scene_040.jpg
# 14    threat    safe   Scenes_selected/scene_040.jpg
# 15    threat    safe   Scenes_selected/scene_068.jpg
# 21    threat    safe  Scenes_selected/scene_098.jpeg
# 23    threat    safe  Scenes_selected/scene_098.jpeg
# 24    threat    safe  Scenes_selected/scene_098.jpeg
# 25    threat    safe   Scenes_selected/scene_058.jpg
# 30    threat    safe  Scenes_selected/scene_098.jpeg
# 31    threat    safe   Scenes_selected/scene_040.jpg
# 32    threat    safe   Scenes_selected/scene_058.jpg
# 38    threat    safe   Scenes_selected/scene_086.jpg
# 41    threat    safe   Scenes_selected/scene_083.jpg
# 42    threat    safe   Scenes_selected/scene_058.jpg
# 45    threat    safe  Scenes_selected/scene_098.jpeg
# 48    threat    safe  Scenes_selected/scene_098.jpeg
# 49    threat    safe  Scenes_selected/scene_098.jpeg
# 50    threat    safe   Scenes_selected/scene_075.jpg
# 53    threat    safe   Scenes_selected/scene_058.jpg
# 55    threat    safe   Scenes_selected/scene_083.jpg
# 56    threat    safe  Scenes_selected/scene_069.jpeg
# 57    threat    safe   Scenes_selected/scene_058.jpg
# 58    threat    safe   Scenes_selected/scene_040.jpg
# 60    threat    safe  Scenes_selected/scene_069.jpeg
# 61    threat    safe   Scenes_selected/scene_086.jpg
# 62    threat    safe  Scenes_selected/scene_069.jpeg
# 64    threat    safe   Scenes_selected/scene_068.jpg
# 66    threat    safe   Scenes_selected/scene_038.jpg
# 74    threat    safe   Scenes_selected/scene_038.jpg
# 77    threat    safe   Scenes_selected/scene_058.jpg
# 78    threat    safe  Scenes_selected/scene_069.jpeg
# 79    threat    safe   Scenes_selected/scene_038.jpg
# 80    threat    safe   Scenes_selected/scene_068.jpg
# 83    threat    safe   Scenes_selected/scene_083.jpg
# 84    threat    safe   Scenes_selected/scene_038.jpg
# 85    threat    safe   Scenes_selected/scene_038.jpg
# 86    threat    safe   Scenes_selected/scene_040.jpg
# 89    threat    safe   Scenes_selected/scene_086.jpg
# 90    threat    safe   Scenes_selected/scene_038.jpg
# 93    threat    safe   Scenes_selected/scene_068.jpg
# 96    threat    safe  Scenes_selected/scene_069.jpeg
# 97    threat    safe   Scenes_selected/scene_040.jpg
# 99    threat    safe   Scenes_selected/scene_075.jpg
# 101   threat    safe  Scenes_selected/scene_069.jpeg
# 102   threat    safe   Scenes_selected/scene_038.jpg
# 103   threat    safe   Scenes_selected/scene_058.jpg
# 104   threat    safe   Scenes_selected/scene_075.jpg
# 109   threat    safe  Scenes_selected/scene_098.jpeg
#
#                            opp_foil  test1_thisRepN  test1_thisTrialN  \
# 3     Scenes_selected/scene_008.jpg             0.0               0.0
# 4    Scenes_selected/scene_097.jpeg             0.0               1.0
# 6     Scenes_selected/scene_006.jpg             0.0               3.0
# 7     Scenes_selected/scene_008.jpg             0.0               4.0
# 9     Scenes_selected/scene_076.jpg             0.0               6.0
# 10    Scenes_selected/scene_073.jpg             0.0               7.0
# 11   Scenes_selected/scene_097.jpeg             0.0               8.0
# 12    Scenes_selected/scene_008.jpg             0.0               9.0
# 14    Scenes_selected/scene_073.jpg             0.0              11.0
# 15    Scenes_selected/scene_054.jpg             0.0              12.0
# 21    Scenes_selected/scene_008.jpg             0.0              18.0
# 23    Scenes_selected/scene_008.jpg             0.0              20.0
# 24   Scenes_selected/scene_063.jpeg             0.0              21.0
# 25    Scenes_selected/scene_006.jpg             0.0              22.0
# 30    Scenes_selected/scene_076.jpg             0.0              27.0
# 31    Scenes_selected/scene_008.jpg             0.0              28.0
# 32    Scenes_selected/scene_006.jpg             0.0              29.0
# 38    Scenes_selected/scene_008.jpg             0.0              35.0
# 41   Scenes_selected/scene_063.jpeg             0.0              38.0
# 42   Scenes_selected/scene_097.jpeg             0.0              39.0
# 45    Scenes_selected/scene_008.jpg             0.0              42.0
# 48   Scenes_selected/scene_063.jpeg             0.0              45.0
# 49    Scenes_selected/scene_054.jpg             0.0              46.0
# 50    Scenes_selected/scene_008.jpg             0.0              47.0
# 53    Scenes_selected/scene_054.jpg             0.0              50.0
# 55    Scenes_selected/scene_073.jpg             0.0              52.0
# 56    Scenes_selected/scene_073.jpg             0.0              53.0
# 57   Scenes_selected/scene_097.jpeg             0.0              54.0
# 58   Scenes_selected/scene_063.jpeg             0.0              55.0
# 60    Scenes_selected/scene_006.jpg             0.0              57.0
# 61    Scenes_selected/scene_008.jpg             0.0              58.0
# 62    Scenes_selected/scene_073.jpg             0.0              59.0
# 64    Scenes_selected/scene_006.jpg             0.0              61.0
# 66    Scenes_selected/scene_054.jpg             0.0              63.0
# 74    Scenes_selected/scene_054.jpg             0.0              71.0
# 77    Scenes_selected/scene_006.jpg             0.0              74.0
# 78   Scenes_selected/scene_097.jpeg             0.0              75.0
# 79    Scenes_selected/scene_042.jpg             0.0              76.0
# 80    Scenes_selected/scene_008.jpg             0.0              77.0
# 83    Scenes_selected/scene_032.jpg             0.0              80.0
# 84    Scenes_selected/scene_042.jpg             0.0              81.0
# 85    Scenes_selected/scene_032.jpg             0.0              82.0
# 86    Scenes_selected/scene_054.jpg             0.0              83.0
# 89   Scenes_selected/scene_063.jpeg             0.0              86.0
# 90    Scenes_selected/scene_073.jpg             0.0              87.0
# 93    Scenes_selected/scene_042.jpg             0.0              90.0
# 96    Scenes_selected/scene_073.jpg             0.0              93.0
# 97   Scenes_selected/scene_063.jpeg             0.0              94.0
# 99   Scenes_selected/scene_097.jpeg             0.0              96.0
# 101  Scenes_selected/scene_097.jpeg             0.0              98.0
# 102   Scenes_selected/scene_073.jpg             0.0              99.0
# 103  Scenes_selected/scene_097.jpeg             0.0             100.0
# 104  Scenes_selected/scene_063.jpeg             0.0             101.0
# 109   Scenes_selected/scene_006.jpg             0.0             106.0
#
#      test1_thisN  ...  text_4_started  session  participant  \
# 3            0.0  ...             NaN      1.0         53.0
# 4            1.0  ...             NaN      1.0         53.0
# 6            3.0  ...             NaN      1.0         53.0
# 7            4.0  ...             NaN      1.0         53.0
# 9            6.0  ...             NaN      1.0         53.0
# 10           7.0  ...             NaN      1.0         53.0
# 11           8.0  ...             NaN      1.0         53.0
# 12           9.0  ...             NaN      1.0         53.0
# 14          11.0  ...             NaN      1.0         53.0
# 15          12.0  ...             NaN      1.0         53.0
# 21          18.0  ...             NaN      1.0         53.0
# 23          20.0  ...             NaN      1.0         53.0
# 24          21.0  ...             NaN      1.0         53.0
# 25          22.0  ...             NaN      1.0         53.0
# 30          27.0  ...             NaN      1.0         53.0
# 31          28.0  ...             NaN      1.0         53.0
# 32          29.0  ...             NaN      1.0         53.0
# 38          35.0  ...             NaN      1.0         53.0
# 41          38.0  ...             NaN      1.0         53.0
# 42          39.0  ...             NaN      1.0         53.0
# 45          42.0  ...             NaN      1.0         53.0
# 48          45.0  ...             NaN      1.0         53.0
# 49          46.0  ...             NaN      1.0         53.0
# 50          47.0  ...             NaN      1.0         53.0
# 53          50.0  ...             NaN      1.0         53.0
# 55          52.0  ...             NaN      1.0         53.0
# 56          53.0  ...             NaN      1.0         53.0
# 57          54.0  ...             NaN      1.0         53.0
# 58          55.0  ...             NaN      1.0         53.0
# 60          57.0  ...             NaN      1.0         53.0
# 61          58.0  ...             NaN      1.0         53.0
# 62          59.0  ...             NaN      1.0         53.0
# 64          61.0  ...             NaN      1.0         53.0
# 66          63.0  ...             NaN      1.0         53.0
# 74          71.0  ...             NaN      1.0         53.0
# 77          74.0  ...             NaN      1.0         53.0
# 78          75.0  ...             NaN      1.0         53.0
# 79          76.0  ...             NaN      1.0         53.0
# 80          77.0  ...             NaN      1.0         53.0
# 83          80.0  ...             NaN      1.0         53.0
# 84          81.0  ...             NaN      1.0         53.0
# 85          82.0  ...             NaN      1.0         53.0
# 86          83.0  ...             NaN      1.0         53.0
# 89          86.0  ...             NaN      1.0         53.0
# 90          87.0  ...             NaN      1.0         53.0
# 93          90.0  ...             NaN      1.0         53.0
# 96          93.0  ...             NaN      1.0         53.0
# 97          94.0  ...             NaN      1.0         53.0
# 99          96.0  ...             NaN      1.0         53.0
# 101         98.0  ...             NaN      1.0         53.0
# 102         99.0  ...             NaN      1.0         53.0
# 103        100.0  ...             NaN      1.0         53.0
# 104        101.0  ...             NaN      1.0         53.0
# 109        106.0  ...             NaN      1.0         53.0
#
#                         date     expName  psychopyVersion  frameRate  \
# 3    2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 4    2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 6    2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 7    2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 9    2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 10   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 11   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 12   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 14   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 15   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 21   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 23   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 24   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 25   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 30   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 31   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 32   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 38   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 41   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 42   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 45   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 48   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 49   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 50   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 53   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 55   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 56   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 57   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 58   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 60   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 61   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 62   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 64   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 66   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 74   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 77   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 78   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 79   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 80   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 83   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 84   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 85   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 86   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 89   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 90   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 93   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 96   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 97   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 99   2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 101  2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 102  2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 103  2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 104  2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
# 109  2023-05-10_15h43.31.699  src_mem.py         2022.2.4  60.037668
#
#     Unnamed: 45  run_num  Unnamed: 41
# 3           NaN        1          NaN
# 4           NaN        1          NaN
# 6           NaN        1          NaN
# 7           NaN        1          NaN
# 9           NaN        1          NaN
# 10          NaN        1          NaN
# 11          NaN        1          NaN
# 12          NaN        1          NaN
# 14          NaN        1          NaN
# 15          NaN        1          NaN
# 21          NaN        1          NaN
# 23          NaN        1          NaN
# 24          NaN        1          NaN
# 25          NaN        1          NaN
# 30          NaN        1          NaN
# 31          NaN        1          NaN
# 32          NaN        1          NaN
# 38          NaN        1          NaN
# 41          NaN        1          NaN
# 42          NaN        1          NaN
# 45          NaN        1          NaN
# 48          NaN        1          NaN
# 49          NaN        1          NaN
# 50          NaN        1          NaN
# 53          NaN        1          NaN
# 55          NaN        1          NaN
# 56          NaN        1          NaN
# 57          NaN        1          NaN
# 58          NaN        1          NaN
# 60          NaN        1          NaN
# 61          NaN        1          NaN
# 62          NaN        1          NaN
# 64          NaN        1          NaN
# 66          NaN        1          NaN
# 74          NaN        1          NaN
# 77          NaN        1          NaN
# 78          NaN        1          NaN
# 79          NaN        1          NaN
# 80          NaN        1          NaN
# 83          NaN        1          NaN
# 84          NaN        1          NaN
# 85          NaN        1          NaN
# 86          NaN        1          NaN
# 89          NaN        1          NaN
# 90          NaN        1          NaN
# 93          NaN        1          NaN
# 96          NaN        1          NaN
# 97          NaN        1          NaN
# 99          NaN        1          NaN
# 101         NaN        1          NaN
# 102         NaN        1          NaN
# 103         NaN        1          NaN
# 104         NaN        1          NaN
# 109         NaN        1          NaN
#
# [54 rows x 48 columns]

# %%
safe_runs_src = [Sr1src, Sr2src, Sr3src, Sr4src, Sr5src]
threat_runs_src = [Tr1src, Tr2src, Tr3src, Tr4src, Tr5src]

print(safe_runs_src, threat_runs_src)

allSM_df['safe_runsSM'] = str(safe_runs_src)
allSM_df['threat_runsSM'] = str(threat_runs_src)
# Out:
# [0.7407407407407407, 0.6296296296296297, 0.7166666666666667, 0.6111111111111112, 0.7666666666666667] [0.46296296296296297, 0.6481481481481481, 0.6458333333333334, 0.6851851851851852, 0.7083333333333334]

# %%
pt_dt = 'C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/'
os.makedirs(pt_dt, exist_ok=True)  
allSM_df.to_csv(pt_dt+"%s_ptSM_summary.csv"%pt_num, index = True, header = True )

# %%
allSM_df.columns
# Out:
# Index(['test_object', 'correct_context', 'tested_valence', 'same_val',
#        'opp_val', 'same_foil', 'opp_foil', 'test1_thisRepN',
#        'test1_thisTrialN', 'test1_thisN', 'test1_thisIndex', 'text_9_started',
#        'key_resp_6_started', 'key_resp_6_keys', 'key_resp_6_rt',
#        'text_11_started', 'key_resp_7_started', 'key_resp_7_keys',
#        'key_resp_7_rt', 'text_13_started', 'key_resp_8_started',
#        'key_resp_8_keys', 'key_resp_8_rt', 'text_12_started',
#        'text_12_stopped', 'text_started', 'object_cue_started',
#        'correct_cntxt_started', 'foil_same_started', 'foil_opp_started',
#        'key_resp_started', 'corrAns', 'samekey', 'oppkey', 'key_resp_keys',
#        'key_resp_corr', 'key_resp_rt', 'text_stopped', 'text_4_started',
#        'session', 'participant', 'date', 'expName', 'psychopyVersion',
#        'frameRate', 'Unnamed: 45', 'run_num', 'Unnamed: 41', 'run_sm',
#        'allrun_src', 'safe_runsSM', 'threat_runsSM'],
#       dtype='object')

# %%
pt_dt = 'C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/'
dt = pd.read_csv(pt_dt+"%s_ptSM_summary.csv"%pt_num)

# %%
shrt_df = pd.DataFrame({ 
                        'tested_valence': dt.tested_valence,
                        'same_val': dt.same_val,
                        'opp_val':dt.opp_val,
                        'resp': dt.key_resp_keys,
                        'acc':dt.key_resp_corr,
                        'rt': dt.key_resp_rt, 
                        'runSM': dt.run_sm,
                        'allruns': dt.allrun_src,
                        'corr_key': dt.corrAns,
                        'samekey':dt.samekey,
                        'oppkey':dt.oppkey,
                        'safe_runsSM': dt.safe_runsSM,
                        'threat_runsSM': dt.threat_runsSM})

# %%
srcmem_corr = []
srcmem_incor = []
srcmem_miss = []

safe_srcmem_corr = []
safe_srcmem_incor = []
safe_srcmem_miss = []

threat_srcmem_corr = []
threat_srcmem_incor = []
threat_srcmem_miss = []

all_safe = []
all_threat = []


for index, row in shrt_df.iterrows():
    if shrt_df.acc[index] == 1:
        srcmem_corr.append(shrt_df.tested_valence[index])
        
    if shrt_df.tested_valence[index] == 'SAFE':
        all_safe.append(shrt_df.tested_valence[index])
        
    if (shrt_df.acc[index] == 1) and (shrt_df.tested_valence[index] == 'SAFE'):
        safe_srcmem_corr.append(1)
        
    if shrt_df.tested_valence[index] == 'THREAT':
        all_threat.append(shrt_df.tested_valence[index])
        
    if (shrt_df.acc[index] == 1) and (shrt_df.tested_valence[index] == 'THREAT'):
        threat_srcmem_corr.append(1)
        
        
SM = len(srcmem_corr)/len(shrt_df)
pt_SM.append(SM)

ls_runSM.append(shrt_df.allruns[3])
safe_ls_runSM.append(shrt_df.safe_runsSM[3])
threat_ls_runSM.append(shrt_df.threat_runsSM[3]) 

print(len(all_safe))
print(len(all_threat))

print(len(safe_srcmem_corr))
print(len(threat_srcmem_corr))

prop_safe_corr = len(safe_srcmem_corr)/len(all_safe)
prop_threat_corr = len(threat_srcmem_corr)/len(all_threat)

safe_pt_SM.append(prop_safe_corr)
threat_pt_SM.append(prop_threat_corr)
# Out:
# 282
# 258
# 196
# 162

# %% [markdown]
# ## By pt valence

# %%
x = ['Safe', 'Threat']
y = [prop_safe_corr, prop_threat_corr]
print(y)
plt.bar(x, y, width=0.8, bottom=None, color = ['grey', 'purple'], align='center', data=None)
plt.ylim(0, 1)
plt.xlabel("Context", fontsize = "medium")
plt.xticks(fontsize = "medium")
plt.ylabel("Mean accuracy", fontsize = "medium")
plt.yticks(fontsize = "medium")
plt.title("%s_Source memory by context valence"%pt_num, fontsize = "small")
# Out:
# [0.6950354609929078, 0.627906976744186]
# Text(0.5, 1.0, '53.0_Source memory by context valence')

# %%
SMdf = pd.DataFrame({'Mean_accuracy':pt_SM,
                     'Mean_safe': safe_pt_SM,
                     'Mean_threat': threat_pt_SM,
                     'Runs_SM':ls_runSM,
                    'Safe_runsSM': safe_ls_runSM,
                    'Threat_runsSM': threat_ls_runSM})
SMdf.to_csv(pt_dt+"SMsummary_newbatch.csv", index = True, header = True)
SMdf
# Out:
#    Mean_accuracy  Mean_safe  Mean_threat  \
# 0       0.662963   0.695035     0.627907
#
#                                              Runs_SM  \
# 0  [0.6018518518518519, 0.6388888888888888, 0.685...
#
#                                          Safe_runsSM  \
# 0  [0.7407407407407407, 0.6296296296296297, 0.716...
#
#                                        Threat_runsSM
# 0  [0.46296296296296297, 0.6481481481481481, 0.64...

# %% [markdown]
# ## Group Graphs

# %%
# %config InlineBackend.figure_format = 'retina'
plt.style.use('bmh')
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['axes.grid'] = False
plt.rc('font', serif='Helvetica Neue') 
plt.rcParams['lines.markeredgecolor'] = 'w'
plt.rcParams['lines.markeredgewidth'] = 0.5
plt.rcParams['figure.figsize'] = [8, 6]
plt.rcParams['svg.fonttype']= 'none'
plt.rcParams.update({'font.size': 24})
plt.rc('xtick',labelsize=24)
plt.rc('ytick',labelsize=24)

# %%
sum_srcdt = pd.read_csv('C:/Users/ayesh/Desktop/Gradstuff/Temp_mem2022/summary_data/SMsummary.csv')
sum_srcdt.head()
len(sum_srcdt)
# Out:
# 39

# %%
#runs = [1,2,3]
runs = [1,2,3,4,5]
for index, row in sum_srcdt.iterrows():
    b = sum_srcdt.Runs_SM[index]
    g= b.replace('[','')
    h = g.replace(']','')
    res = [float(idx) for idx in h.split(', ')]
    plt.plot(runs, res, linestyle="-.")
    plt.title("All participants", fontsize = 24)
plt.xlabel("Runs")
plt.ylabel("Accuracy")
plt.xticks(runs)
plt.ylim(0,1)
plt.show()

# %%
totalpts = len(sum_srcdt)
for index, row in sum_srcdt.iterrows():
    b = sum_srcdt.Safe_runsSM[index]
    g= b.replace('[','')
    h = g.replace(']','')
    res = [float(idx) for idx in h.split(', ')]
    plt.plot(runs, res, linestyle="-", color= "grey", label = "Safe")
    plt.title ("All participants (N = %s) source mem"%totalpts, fontsize = 24)
for index, row in sum_srcdt.iterrows():
    b = sum_srcdt.Threat_runsSM[index]
    g= b.replace('[','')
    h = g.replace(']','')
    res = [float(idx) for idx in h.split(', ')]
    plt.plot(runs, res, linestyle="--", color = "purple", label = "Threat")
    plt.title("All participants (N = %s) source mem"%totalpts, fontsize = 24)

plt.xlabel("Runs")
plt.ylabel("Accuracy")
plt.xticks(runs)
plt.ylim(0,1)
#plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 18)
plt.show()

# %%
sum_srcdt
# Out:
#     Unnamed: 0  Subs  Mean_accuracy  Mean_safe  Mean_threat  \
# 0            0    32       0.814815   0.811594     0.818182
# 1            1    33       0.581481   0.579710     0.583333
# 2            2    34       0.698148   0.688889     0.707407
# 3            3    35       0.714815   0.733333     0.696296
# 4            4    36       0.744485   0.720430     0.769811
# 5            5    37       0.731481   0.731061     0.731884
# 6            6    38       0.842593   0.821970     0.862319
# 36  [0.7777777777777778, 0.8333333333333334, 0.870...   0.500000     0.641026
# 37  [0.5740740740740741, 0.6481481481481481, 0.462...   0.539683     0.472868
# 38  [0.7222222222222222, 0.8518518518518519, 0.796...   0.512195     0.420455
#
#     Safe_opp  Threat_opp
# 0   0.480769    0.416667
# 1   0.491379    0.527273
# 2   0.464286    0.443038
# 3   0.513889    0.463415
# 4   0.474359    0.475410
# 5   0.633803    0.486486
# 6   0.468085    0.342105
# 7   0.528736    0.515789
# 8   0.528169    0.520548
# 9   0.333333    0.550000
# 10  0.504587    0.478723
# 11  0.434426    0.506667
# 12  0.530864    0.463768
# 13  0.368421    0.521739
# 14  0.430000    0.516484
# 15  0.622642    0.456140
# 16  0.465116    0.489362
# 17  0.561151    0.381250
# 18  0.562500    0.375000
# 19  0.508333    0.528846
# 20  0.523256    0.447917
# 21  0.505882    0.575342
# 22  0.544828    0.514085
# 23  0.452381    0.441176
# 24  0.442105    0.470588
# 25  0.528302    0.444444
# 26  0.416667    0.538462
# 27  0.471698    0.454545
# 28  0.483871    0.517986
# 29  0.666667    0.384615
# 30  0.500000    0.403101
# 31  0.567568    0.425532
# 32  0.510067    0.496552
# 33  0.380952    0.589744
# 34  0.546667    0.496552
# 35  0.514124    0.540373
# 36  0.500000    0.358974
# 37  0.460317    0.527132
# 38  0.487805    0.579545

# %%
A = sum_srcdt.Mean_safe
B = sum_srcdt.Mean_threat
C = [a - b for a, b in zip(A, B)]
C
x_range = range(1, totalpts + 1)
plt.xlim (0, 23)
plt.xticks(x_range, fontsize = "small")
plt.yticks(fontsize = "small")
plt.scatter(x_range, C, marker='*', color = "black", s = 80)
plt.xlabel("Participant", fontsize = "small")
plt.ylabel("Accuracy difference (Safe-Threat)", fontsize = "small")
plt.title("Source memory by valence", fontsize = "small")
plt.axhline(y = 0.0, color = 'k', linestyle = '-')

# %%
x_axis = np.arange(totalpts)
  
plt.bar(x_axis - 0.2, A, 0.4, label = 'Safe', color = "grey")
plt.bar(x_axis + 0.2, B, 0.4, label = 'Threat', color = "purple")

plt.xlabel("Participants")
plt.ylabel("Source Memory Accuracy")
plt.title("Source memory by valence")
x_range = range(0, totalpts + 1)
y_range = [0.0, 0.2, 0.4, 0.6, 0.8]
plt.xlim (-1, 10)
plt.xticks(x_range, fontsize = "x-small")
plt.yticks(y_range, fontsize = "x-small")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 18)
plt.xticks(x_range, fontsize = "x-small")
#plt.show()
plt.savefig('srcmem_val.pdf')

# %%
x_axis = np.arange(totalpts)
  
plt.scatter(x_axis - 0.2, A, marker = 'o', label = 'Safe', color = "grey", s = 80)
plt.scatter(x_axis + 0.2, B, marker = '*', label = 'Threat', color = "purple", s = 80)

plt.xlabel("Participants")
plt.ylabel("Source Memory Accuracy")
plt.title("Source memory by valence")
x_range = range(0, totalpts + 1)
y_range = [0.0, 0.2, 0.4, 0.6, 0.8]
plt.xlim (-1, 10)
plt.xticks(x_range, fontsize = "x-small")
plt.yticks(y_range, fontsize = "x-small")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize = 18)
plt.show()

# %%
x_range
# Out:
# range(0, 40)

# %%
len(B)
# Out:
# 39
